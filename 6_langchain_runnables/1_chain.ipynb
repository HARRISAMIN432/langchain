# %%
import random

class JaliLLM:
    def __init__(self):
        print('LLM Created')
        
    def predict(self, prompt):
        response_list = [
            'Islamabad is the capital of Pakistan',
            'PSL is a mediocre Pakistani cricket league',
            'AI stands for Artificial Intelligence'
        ]
        return {'Response': random.choice(response_list)}

# %%
llm = JaliLLM()
# Out:
# LLM Created

# %%
llm.predict('Hello from Harris')
# Out:
# {'Response': 'AI stands for Artificial Intelligence'}

# %%
class JaliPromptTemplate:
    def __init__(self, template, input_variables):
        self.template = template
        self.input_variables = input_variables
        
    def format(self, input_dict):
        return self.template.format(**input_dict)

# %%
template = JaliPromptTemplate(
    template='Write a poem about {topic}',
    input_variables=['topic']
)

template.format({"topic":'Cricket'})
# Out:
# 'Write a poem about Cricket'

# %%
llm.predict(template)
# Out:
# {'Response': 'Islamabad is the capital of Pakistan'}

# %%
class NakliLLMChain:
    def __init__(self, llm, prompt):
        self.llm = llm
        self.prompt = prompt
        
    def run(self, input_dict):
        final_prompt=self.prompt.format(input_dict)
        result=self.llm.predict(final_prompt)
        return result['Response']

# %%
template = JaliPromptTemplate(
    template='Write a poem about {topic}',
    input_variables=['topic']
)

template.format({"topic":'Cricket'})
# Out:
# 'Write a poem about Cricket'

# %%
llm = JaliLLM()
# Out:
# LLM Created

# %%
chain = NakliLLMChain(llm, template)

# %%
chain.run({'topic': 'papacheeto'})
# Out:
# 'AI stands for Artificial Intelligence'
